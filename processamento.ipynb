# %% [markdown]
# #Imports

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from math import sin, cos, sqrt, atan2, radians
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %% [markdown]
# #Campos

# %%
drop_col    = ['isSearchEngineCrawler','id','businessContext','pathname','experiments','remarks',
               'street','furniture','firstPublicationDate','lastPublicationDate','city',
               'stateAcronym','neighborhood','region_name']
numeric_col = ['condoPrice','homeProtection','bedrooms','area','parkingSpaces',
               'rentalGuarantee_min','rentalGuarantee_max','suites','iptu','bathrooms',
               'floor','totalCost','rentPrice','region_id','lat','lng']
bool_col = ['hasFurniture','acceptsPets','isNearSubway']
categorical_col = ['iptuType','rentalAdministrator','type','availabilityType','ownership']

# %% [markdown]
# #Carregamento dos dados principais

# %%
path = '/content/drive/MyDrive/TCC_PUC/Pickle/my_data.pkl'
df = pd.read_pickle(path)
df=df.dropna(subset=['firstPublicationDate','lat','lng'],axis=0)                      #remove linhas sem data de publicação
df[['firstPublicationDate','lastPublicationDate']] = df[['firstPublicationDate','lastPublicationDate']].apply(pd.to_datetime)
df[numeric_col] = df[numeric_col].apply(pd.to_numeric)
df['region_name'] = df.apply(lambda r: r['region_name'].replace('\n', ''), axis=1) # retirar quebra de linhas nos nomes dos bairros
for col in bool_col:
  df[col] = df[col].astype(int)
df=df.dropna(axis=1,how='all')                                            #remove colunas com todos os valores nulos

# %% [markdown]
# ##Carregamento dados do enriquecimento

# %%
em = pd.read_csv('/content/drive/MyDrive/TCC_PUC/Pickle/estacoes_metro.csv')
em.head(5)
# Out:
#                   station      line company        lng        lat
# 0                      SÉ      AZUL   METRO -46.633088 -23.551000
# 1    CORINTHIANS-ITAQUERA  VERMELHA   METRO -46.471078 -23.542305
# 2             ARTUR ALVIM  VERMELHA   METRO -46.484590 -23.540288
# 3               PATRIARCA  VERMELHA   METRO -46.501382 -23.531183
# 4   GUILHERMINA-ESPERANÇA  VERMELHA   METRO -46.516548 -23.529263
# ..                    ...       ...     ...        ...        ...
# 88             CAMPO BELO     LILAS   METRO -46.682319 -23.618974
# 89             SÃO MATEUS     PRATA   METRO -46.476682 -23.612088
# 90        FAZENDA DA JUTA     PRATA   METRO -46.487472 -23.611688
# 91              SAPOPEMBA     PRATA   METRO -46.501427 -23.614753
# 92        JARDIM PLANALTO     PRATA   METRO -46.507052 -23.607391
#
# [93 rows x 5 columns]

# %% [markdown]
# ##Funções

# %%
def upper_bound(df,col,k=1.5):
  return df[col].quantile(0.75)+k*(df[col].quantile(0.75)-df[col].quantile(0.25))

def drop_outliers(df,cols):
  for col in cols:
    df = df[df[col] < upper_bound(df.copy(),col,k=3)]
  return df

def fill_mode(df,cols):
  for col in cols:
    filler = df[col].mode()[0]
    df[col] = df.apply(lambda r: r[col] if r[col] else filler, axis=1)
  return df

def fill_val(df,col,filler):
  df[col] = df.apply(lambda r: r[col] if not np.isnan(r[col]) else filler, axis=1)
  return df

def geo_distance(lat1,lon1,lat2,lon2):
  # https://en.wikipedia.org/wiki/Haversine_formula
  # https://stackoverflow.com/questions/19412462/
  R = 6373000.0 #raio da terra em metros
  lat1 = radians(lat1)
  lon1 = radians(lon1)
  lat2 = radians(lat2)
  lon2 = radians(lon2)
  dlon = lon2 - lon1
  dlat = lat2 - lat1
  a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
  return R * 2 * atan2(sqrt(a), sqrt(1 - a))

def geo_matrix(lat,lon):
  mt = em.copy()
  mt['distance'] = mt.apply(lambda r: geo_distance(lat,lon,r['lat'],r['lng']), axis=1)
  return mt.sort_values('distance')

# %% [markdown]
# ##Processamento IPTU

# %%
# Tem IPTU?
df['has_iptu'] = df.apply(lambda r: r['iptu']!=0, axis=1)
# Cálculo da razão IPTU pelo Custo total
df['iptu_ratio'] = df.apply(lambda r: r['iptu']/r['totalCost'], axis=1)

# %%
# Filtragem e correção dos valoes de IPTU
ub = upper_bound(df.copy(),'iptu_ratio')
iptu_df = df[df['iptu_ratio'] > ub]
df = df[df['iptu_ratio'] < upper_bound(iptu_df.copy(),'iptu_ratio')]
df['totalCost'] = df.apply(lambda r: r['totalCost']-r['iptu']*11/12 if r['iptu_ratio'] > ub else r['totalCost'], axis=1)
df['iptu'] = df.apply(lambda r: r['iptu']/12 if r['iptu_ratio'] > ub else r['iptu'], axis=1)
print(df['iptu_ratio'].mean())
df = df.drop(['iptu_ratio'],axis=1)
# Out:
# 0.03004651766345497

# %% [markdown]
# ##Valores extremos

# %%
#Exclusão dos registros de outliers
display(df.shape)
df = drop_outliers(df.copy(),['iptu','totalCost','area','rentPrice','floor','condoPrice'])
display(df.shape)
# Out:
# (9023, 40)
# (6915, 40)

# %% [markdown]
# ##Registros ausentes

# %%
#Preenchimento com o valor mais frequente
df = fill_mode(df.copy(),['rentalAdministrator','availabilityType'])
#Preenchimento com zero
df = fill_val(df.copy(),'floor',0.0)

# %% [markdown]
# ##Enriquecimento de dados

# %%
#Cálculo da distância para a estação de metrô
df['metro_dist'] = df.apply(lambda r: geo_matrix(r['lat'],r['lng']).iloc[0]['distance'], axis=1)

# %% [markdown]
# #Análise exploratória de dados

# %%
#Loop para geração de gráficos
for c in categorical_col:
  plt.figure(figsize=(3,3))
  df['Campo'] = c
  a = sns.histplot(data=df,x='Campo',hue=c,stat='percent',multiple='stack')
  plt.show()
df=df.drop(columns=['Campo'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6915 entries, 893937653 to 893590256
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   firstPublicationDate   6915 non-null   datetime64[ns, UTC]
#  1   condoPrice             6915 non-null   int64
#  2   iptuType               6915 non-null   object
#  3   homeProtection         6915 non-null   int64
#  4   neighborhood           6915 non-null   object
#  5   rentalAdministrator    6915 non-null   object
#  6   bedrooms               6915 non-null   int64
#  7   id                     6915 non-null   object
#  8   condoType              6915 non-null   object
#  9   region_name            6915 non-null   object
#  10  area                   6915 non-null   int64
#  11  businessContext        6915 non-null   object
#  12  pathname               6915 non-null   object
#  13  isSearchEngineCrawler  6915 non-null   bool
#  14  city                   6915 non-null   object
#  15  type                   6915 non-null   object
#  16  region_id              6915 non-null   int64
#  17  parkingSpaces          6915 non-null   int64
#  18  hasFurniture           6915 non-null   int64
#  19  rentalGuarantee_min    6915 non-null   float64
#  20  acceptsPets            6915 non-null   int64
#  21  suites                 6915 non-null   int64
#  22  iptu                   6915 non-null   float64
#  23  lastPublicationDate    6915 non-null   datetime64[ns, UTC]
#  24  bathrooms              6915 non-null   int64
#  25  availabilityType       6915 non-null   object
#  26  lat                    6915 non-null   float64
#  27  ownership              6915 non-null   object
#  28  floor                  6915 non-null   float64
#  29  stateAcronym           6915 non-null   object
#  30  experiments            6915 non-null   object
#  31  totalCost              6915 non-null   float64
#  32  isNearSubway           6915 non-null   int64
#  33  lng                    6915 non-null   float64
#  34  rentPrice              6915 non-null   int64
#  35  rentalGuarantee_max    6915 non-null   float64
#  36  remarks                5943 non-null   object
#  37  street                 6915 non-null   object
#  38  furniture              1522 non-null   object
#  39  has_iptu               6915 non-null   bool
#  40  metro_dist             6915 non-null   float64
# dtypes: bool(2), datetime64[ns, UTC](2), float64(8), int64(12), object(17)
# memory usage: 2.4+ MB

# %% [markdown]
# ##Feature Engineering

# %%
df['comodos'] = df.apply(lambda r: r['bedrooms']+r['parkingSpaces']+r['suites']+r['bathrooms'], axis=1)

# %% [markdown]
# ##Redução Dimensionalidade

# %%
bairros = pd.DataFrame(df['region_name'].value_counts()).sort_values(by='region_name',ascending=False)
bairros
# Out:
#                   region_name
# Santa Cecília             436
# Consolação                345
# Mooca                     312
# Bela Vista                297
# Centro                    287
# ...                       ...
# Pacaembu                    1
# Santa Maria                 1
# Vila Nina                   1
# Gopoúva                     1
# Parque São Lucas            1
#
# [126 rows x 1 columns]

# %%
# Gráfico de pareto
fig, ax1 = plt.subplots(figsize=(20,5)) # initializes figure and plots
ax2 = ax1.twinx() #
lista = df[['region_name','region_id']].groupby(['region_name']).count().sort_values('region_id',ascending=False)
lista['pareto'] =  lista['region_id'].cumsum()/lista['region_id'].sum()*100
g = sns.barplot(data=lista,x=lista.index,y='region_id',ax=ax1)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
sns.lineplot(data=lista,x=lista.index,y='pareto',ax=ax2)
plt.show()

# %%
#Cálculo da linha de corte
lista[lista['pareto']<80].min()
# Out:
# region_id    69.000000
# pareto        6.305134
# dtype: float64

# %% [markdown]
# ##Análise multivariada

# %%
sns.scatterplot(data=df,x='lng',y='lat',hue='type',markers=False)

# %%
g = sns.jointplot(data=df, x='rentPrice', y='area',kind="hex")
g.plot_joint(sns.kdeplot,zorder=1, levels=5)

# %%
df.columns
# Out:
# Index(['firstPublicationDate', 'condoPrice', 'iptuType', 'homeProtection',
#        'neighborhood', 'rentalAdministrator', 'bedrooms', 'id', 'condoType',
#        'region_name', 'area', 'businessContext', 'pathname',
#        'isSearchEngineCrawler', 'city', 'type', 'region_id', 'parkingSpaces',
#        'hasFurniture', 'rentalGuarantee_min', 'acceptsPets', 'suites', 'iptu',
#        'lastPublicationDate', 'bathrooms', 'availabilityType', 'lat',
#        'ownership', 'floor', 'stateAcronym', 'experiments', 'totalCost',
#        'isNearSubway', 'lng', 'rentPrice', 'rentalGuarantee_max', 'remarks',
#        'street', 'furniture', 'has_iptu', 'metro_dist', 'comodos'],
#       dtype='object')

# %%
sns.boxplot(data=df,y="totalCost",x='comodos')
plt.show()

# %%
n = df[['bedrooms','suites']]
sns.pairplot(n)
plt.show()

# %%
g = sns.jointplot(data=df, x="lng", y="lat",kind="hex")
g.plot_joint(sns.kdeplot,zorder=1, levels=5)

# %% [markdown]
# #Análise univariada
# ##Boxplot

# %%
cols = numeric_col
n = len(cols)
fig, axes = plt.subplots(n,figsize=(8,2*n))
for a in range(n):
  sns.boxplot(data=df,x=cols[a],ax=axes[a]).set(xlabel='',ylabel=cols[a].upper())
fig.show()

# %% [markdown]
# ##Função densidade de probabilidade

# %%
cols = numeric_col
n = len(cols)
fig, axes = plt.subplots(n,figsize=(8,2*n))
for a in range(n):
  sns.kdeplot(data=df,x=cols[a],ax=axes[a]).set(xlabel='',ylabel=cols[a].upper())
fig.show()

# %%
sns.displot(df, x="totalCost", hue="acceptsPets", kind="kde", fill=True)
plt.show()

# %%
df=df.drop(columns=drop_col) # remover colunas que não serão usadas no modelo

# %%
sns.scatterplot(data=df,x='lng',y='lat',hue='type',markers=False)
# Out:
# <Axes: xlabel='lng', ylabel='lat'>

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,fmt=".2f")
plt.show()

# %% [markdown]
# #Modelo

# %%
df.describe()
# Out:
#         condoPrice  homeProtection     bedrooms         area    region_id  \
# count  6915.000000     6915.000000  6915.000000  6915.000000  6915.000000
# mean    642.552711       36.515401     1.661894    57.890094   974.795806
# std     485.648961       21.642135     0.743452    31.712816  1021.144003
# min       0.000000        7.000000     0.000000     0.000000    42.000000
# 25%     320.000000       21.000000     1.000000    35.000000    61.000000
# 50%     536.000000       31.000000     2.000000    50.000000  1297.000000
# 75%     880.000000       45.000000     2.000000    72.000000  1343.000000
# max    2598.000000      163.000000     5.000000   237.000000  6626.000000
#
#        parkingSpaces  hasFurniture  rentalGuarantee_min  acceptsPets  \
# count    6915.000000   6915.000000          6915.000000  6915.000000
# mean        0.668691      0.256110           707.365293     0.708604
# std         0.727171      0.436515           424.662953     0.454438
# min         0.000000      0.000000           137.500000     0.000000
# 25%         0.000000      0.000000           400.000000     0.000000
# 50%         1.000000      0.000000           590.000000     1.000000
# 75%         1.000000      1.000000           875.000000     1.000000
# max         8.000000      1.000000          2450.000000     1.000000
#
#             suites         iptu    bathrooms          lat        floor  \
# count  6915.000000  6915.000000  6915.000000  6915.000000  6915.000000
# mean      0.379610    98.088913     1.349241   -23.554284     6.202169
# std       0.562615   124.567657     0.640633     0.040143     5.225455
# min       0.000000     0.000000     1.000000   -23.638514     0.000000
# 25%       0.000000     0.000000     1.000000   -23.581184     2.000000
# 50%       0.000000    55.000000     1.000000   -23.552592     5.000000
# 75%       1.000000   140.500000     2.000000   -23.535186     9.000000
# max       4.000000   676.000000     5.000000   -23.462685    29.000000
#
#           totalCost  isNearSubway          lng    rentPrice  \
# count   6915.000000   6915.000000  6915.000000  6915.000000
# mean    3669.614148      0.652495   -46.635183  2829.461171
# std     2120.022789      0.476212     0.039852  1698.651810
# min      571.000000      0.000000   -46.723600   550.000000
# 25%     2097.000000      0.000000   -46.661356  1600.000000
# 50%     3099.000000      1.000000   -46.640759  2360.000000
# 75%     4649.500000      1.000000   -46.610622  3500.000000
# max    12774.000000      1.000000   -46.543063  9800.000000
#
#        rentalGuarantee_max   metro_dist      comodos
# count          6915.000000  6915.000000  6915.000000
# mean           2122.095879  1192.453903     4.059436
# std            1273.988858  1153.272710     2.156536
# min             412.500000    12.446945     1.000000
# 25%            1200.000000   414.632050     2.000000
# 50%            1770.000000   715.741113     3.000000
# 75%            2625.000000  1630.795033     5.000000
# max            7350.000000  7540.450471    16.000000

# %%
pd.DataFrame(df['ownership'].value_counts()).sort_values(by='ownership',ascending=False)
# Out:
#              ownership
# STANDARD          6721
# THIRD_PARTY        194

# %%
df.to_pickle("/content/drive/MyDrive/TCC_PUC/Pickle/processed_data.pkl")

# %%
df.head(15)
# Out:
#            condoPrice   iptuType  homeProtection rentalAdministrator  \
# 893937653           0  NaoExiste             102         QUINTOANDAR
# 893797315         396     Normal              14         QUINTOANDAR
# 893780813         320  NaoExiste              24         QUINTOANDAR
# 893725632         480  NaoExiste              40         QUINTOANDAR
# 893962721        1100     Normal              61         QUINTOANDAR
# 893023681        1300     Normal              44         QUINTOANDAR
# 893010454         800     Normal              60         QUINTOANDAR
# 893956948         371     Normal              49         QUINTOANDAR
# 893946006        1327     Normal             108         QUINTOANDAR
# 893499171        1252     Normal              74         QUINTOANDAR
# 893744886         683     Normal              22         QUINTOANDAR
# 892811842         175     Normal              32         QUINTOANDAR
# 893755896         463  NaoExiste              37         QUINTOANDAR
# 893984811        2300     Normal              51         QUINTOANDAR
# 893691399         323     Normal              17         QUINTOANDAR
#
#            bedrooms          condoType  area                 type  region_id  \
# 893937653         1  IncluidoNoAluguel   108          Apartamento       1916
# 893797315         1             Normal    40  StudioOuKitchenette         55
# 893780813         1             Normal    56          Apartamento         55
# 893725632         1             Normal    22          Apartamento         42
# 893962721         3             Normal   130          Apartamento       1323
# 893023681         2             Normal    86          Apartamento         46
# 893010454         1             Normal    49          Apartamento         72
# 893956948         2             Normal   104          Apartamento         72
# 893946006         3             Normal   164          Apartamento       1304
# 893499171         3             Normal   115          Apartamento         61
# 893744886         2             Normal    57          Apartamento       1310
# 892811842         2             Normal   140          Apartamento       1310
# 893755896         2             Normal    47          Apartamento       1312
# 893984811         3  IncluidoNoAluguel   173          Apartamento       1329
# 893691399         2             Normal    55          Apartamento       1420
#
#            parkingSpaces  hasFurniture  rentalGuarantee_min  acceptsPets  \
# 893937653              0             0              2000.00            0
# 893797315              0             0               276.25            1
# 893780813              0             0               468.75            1
# 893725632              0             0               778.75            1
# 893962721              3             0              1200.00            1
# 893023681              3             0               860.25            0
# 893010454              1             1              1172.50            1
# 893956948              0             0               950.00            0
# 893946006              3             0              2125.00            1
# 893499171              1             0              1450.00            1
# 893744886              1             0               425.00            1
# 892811842              1             0               625.00            1
# 893755896              1             0               725.00            1
# 893984811              1             0              1000.00            1
# 893691399              1             0               318.75            1
#
#            suites        iptu  bathrooms availabilityType        lat  \
# 893937653       0    0.000000          1        IMMEDIATE -23.477206
# 893797315       0   46.000000          1        IMMEDIATE -23.555625
# 893780813       0    0.000000          1        IMMEDIATE -23.560318
# 893725632       0    0.000000          1        IMMEDIATE -23.610465
# 893962721       1  209.000000          3        IMMEDIATE -23.617071
# 893023681       2  209.000000          3        IMMEDIATE -23.603929
# 893010454       1  192.000000          2         FLEXIBLE -23.549695
# 893956948       0  179.000000          1        IMMEDIATE -23.554570
# 893946006       3  355.000000          3        IMMEDIATE -23.531340
# 893499171       1  186.000000          2        IMMEDIATE -23.562737
# 893744886       0  108.000000          2        IMMEDIATE -23.493355
# 892811842       1   32.083333          3        IMMEDIATE -23.502846
# 893755896       1    0.000000          2        IMMEDIATE -23.487376
# 893984811       1  486.000000          2        IMMEDIATE -23.571948
# 893691399       0   34.000000          1        IMMEDIATE -23.464594
#
#           ownership  floor     totalCost  isNearSubway        lng  rentPrice  \
# 893937653  STANDARD    8.0   8309.000000             0 -46.587454       8000
# 893797315  STANDARD    4.0   1589.000000             1 -46.649463       1105
# 893780813  STANDARD    2.0   2267.000000             1 -46.642715       1875
# 893725632  STANDARD    2.0   3715.000000             1 -46.676014       3115
# 893962721  STANDARD    7.0   6294.000000             1 -46.568574       4800
# 893023681  STANDARD    7.0   5083.000000             1 -46.666328       3441
# 893010454  STANDARD   26.0   5863.000000             1 -46.643760       4690
# 893956948  STANDARD    2.0   4497.000000             1 -46.654524       3800
# 893946006  STANDARD   19.0  10510.000000             0 -46.577619       8500
# 893499171  STANDARD    6.0   7462.000000             1 -46.677096       5800
# 893744886  STANDARD    4.0   2557.000000             1 -46.625383       1700
# 892811842  STANDARD    2.0   2803.083333             1 -46.621333       2500
# 893755896  STANDARD    7.0   3475.000000             1 -46.609830       2900
# 893984811  STANDARD   11.0   6940.000000             1 -46.647408       4000
# 893691399  STANDARD    3.0   1682.000000             0 -46.543126       1275
#
#            rentalGuarantee_max  has_iptu   metro_dist  comodos
# 893937653              6000.00     False  1630.795033        2
# 893797315               828.75      True   795.216299        2
# 893780813              1406.25     False   446.416825        2
# 893725632              2336.25     False   716.638104        2
# 893962721              3600.00      True  3433.159580       10
# 893023681              2580.75      True   447.423024       10
# 893010454              3517.50      True   533.690502        5
# 893956948              2850.00      True   666.161043        3
# 893946006              6375.00      True  1021.248408       12
# 893499171              4350.00      True   567.546748        7
# 893744886              1275.00      True   850.349294        5
# 892811842              1875.00      True   352.270383        7
# 893755896              2175.00     False   109.801923        6
# 893984811              3000.00      True   341.331515        7
# 893691399               956.25      True  6358.701245        4
