# %% [markdown]
# #Imports

# %%
# !pip install selectolax
from selectolax.lexbor import LexborHTMLParser
import x
import glob
import json
import requests
import json
import time
import os.path
import glob
import re

# %% [markdown]
# #Carregar lista de imóveis

# %%
f = open('/content/drive/MyDrive/TCC_PUC/quinto.json', 'r')
#transformar de JSON para array
js = json.loads(f.read())
f.close()
ids = []
for c in js['hits']['hits']:
  ids.append(c['_id'])

# %% [markdown]
# ##Verificar registros já baixados

# %%
restantes = ids.copy()
faltantes = []
for f in glob.glob('/content/drive/MyDrive/TCC_PUC/QuintoAndar/*.txt'):
  v = re.findall('\d{9}', f)
  try:
    restantes.remove(v[0])
  except:
    faltantes.append(f)
display(f'Restantes - {len(restantes)}')
display(faltantes)

# %% [markdown]
# ##Funções

# %%
def saveData(r, *args, **kwargs):
    r.hook_called = True
    display('OK')
    display(r.status_code)
    display(r.url.rsplit('/',3))
    display(r.reason)
    return r

# %% [markdown]
# ##Download dos detalhes dos arquivos

# %%
hooks={'response': saveData}
a = 0
b = 0
for id in restantes:
  if not os.path.isfile(f'/content/drive/MyDrive/TCC_PUC/QuintoAndar/{id}.txt'):
    url = f'http://www.quintoandar.com.br/imovel/{id}'
    r = s.get(url)
    if r.status_code == 200:
      f = open(f'/content/drive/MyDrive/TCC_PUC/QuintoAndar/{id}.txt', "a")
      #display(f'Salvando --- /content/drive/MyDrive/TCC_PUC/QuintoAndar/{id}.txt')
      f.write(r.text)
      f.close()
      a = a+1
    display(f'{id} - {r.status_code} ({a})')
  else :
    b = b+1
    display(f'{id} - Já existe ... ({b})')

# %% [markdown]
# ##Processamento das respostas

# %%
# salva o JSON processamo no formato ZIP
fl = '/content/sample_data/json.zip'
x=0
for i in glob.glob('/content/drive/MyDrive/TCC_PUC/QuintoAndar/*.txt'):
  with open(i, 'r') as f:
    try:
      parser = LexborHTMLParser(f.read())
      js = parser.root.css_first("script[type='application/json']").text()
      data = json.loads(js)
      with zipfile.PyZipFile(fl, 'a', zipfile.ZIP_LZMA) as zf:
        zf.writestr(data['query']['houseId']+'.json',json.dumps(data),zipfile.ZIP_LZMA)
      x = x+1
      display(f"Arquivo {x} - {data['query']['houseId']}")
    except:
      display(f'Errro em {i}')
# Out:
# 'Arquivo 1 - 893937653'
# 'Arquivo 2 - 893608146'
# 'Arquivo 3 - 893797315'
# 'Arquivo 4 - 893780813'
# 'Arquivo 5 - 893725632'
# 'Arquivo 6 - 893892888'
# 'Arquivo 7 - 893962721'
# 'Arquivo 8 - 893822846'
# 'Arquivo 9 - 893023681'
# 'Arquivo 10 - 893010454'
# 'Arquivo 11 - 893764424'
# 'Arquivo 12 - 893956948'
# 'Arquivo 13 - 893946006'
# 'Arquivo 14 - 893499171'
# 'Arquivo 15 - 893744886'
# 'Arquivo 16 - 892811842'
# 'Arquivo 17 - 893755896'
# 'Arquivo 18 - 893392892'
# 'Arquivo 19 - 893608813'
# 'Arquivo 20 - 893984811'
# 'Arquivo 21 - 893691399'
# 'Arquivo 22 - 893933854'
# 'Arquivo 23 - 893953685'
# 'Arquivo 24 - 893818682'
# 'Arquivo 25 - 893818684'
# 'Arquivo 26 - 892856367'
# 'Arquivo 27 - 893966736'
# 'Arquivo 28 - 893766319'
# 'Arquivo 29 - 893927253'
# 'Arquivo 30 - 893551108'
# 'Arquivo 31 - 893916254'
# 'Arquivo 32 - 893916251'
# 'Arquivo 33 - 893007180'
# 'Arquivo 34 - 893879331'
# 'Arquivo 35 - 893147790'
# 'Arquivo 36 - 893510943'
# 'Arquivo 37 - 893953750'
# ...

# %%
js = parser.root.css_first("script[type='application/json']").text()
data = json.loads(js)
display(data['query']['houseId'])
# Out:
# '892801836'
